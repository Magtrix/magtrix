# %% [markdown]
# <a href="https://colab.research.google.com/github/Magtrix/magtrix/blob/main/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

token = userdata.get('GITHUB_TOKEN')
# !git clone https://{token}@github.com/Magtrix/MicroLAYS-ideas.git
# Out:
# Cloning into 'MicroLAYS-ideas'...
# remote: Enumerating objects: 637, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 637 (delta 0), reused 1 (delta 0), pack-reused 634 (from 3)
# Receiving objects: 100% (637/637), 221.09 MiB | 16.16 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Updating files: 100% (614/614), done.

# %%
import os
os.listdir('/content/MicroLAYS-ideas')
# Out:
# ['.DS_Store',
#  'data',
#  '.git',
#  'README.md',
#  '.gitattributes',
#  'output',
#  'code',
#  'resources',
#  'report',
#  'PROJECT_CONTEXT.md']
